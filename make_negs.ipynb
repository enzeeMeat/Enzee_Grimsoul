# %%
import glob
from PIL import Image, ImageOps


for name in glob.iglob('bin/n/*.png'):
    print(name)

    
    im = Image.open(name)
    im_invert = ImageOps.invert(im)
    im_invert.save(name, quality=100)
# Out:
# bin/negs\Aissa_Tear.png
# bin/negs\AI_Key.png
# bin/negs\Alchemaical_Gold.png
# bin/negs\Ale.png
# bin/negs\Alter_Core.png
# bin/negs\Animal_Hide.png
# bin/negs\Baked_Pumpkin.png
# bin/negs\Bandage.png
# bin/negs\Basket_with_Direwolfling.png
# bin/negs\Bastard_Sword.png
# bin/negs\Berry_drink.png
# bin/negs\Birch_Log.png
# bin/negs\Birch_Plank.png
# bin/negs\Bitter_Tincture.png
# bin/negs\Black_Halbred.png
# bin/negs\Black_Iron_Shod_Shield.png
# bin/negs\Black_Pannier.png
# bin/negs\Black_Powder.png
# bin/negs\Black_Scimitar.png
# bin/negs\Bone.png
# bin/negs\Bone_Bow.png
# bin/negs\Bone_Mace.png
# bin/negs\Book_Of_Fate.png
# bin/negs\Bowstring.png
# bin/negs\Bridle.png
# bin/negs\Brigandine.png
# bin/negs\Brigandine_Chausses.png
# bin/negs\Brigandine_Gloves.png
# bin/negs\Bronze_Chausses.png
# bin/negs\Bronze_Hauberk.png
# bin/negs\Bronze_Ingot.png
# bin/negs\Buckler.png
# bin/negs\Candle.png
# bin/negs\Candy_Apple.png
# bin/negs\Candy_Cane.png
# bin/negs\Chain.png
# bin/negs\Chainmail_Gauntlets.png
# bin/negs\Chainmail_Sabatons.png
# bin/negs\Chalice.png
# bin/negs\Christmas_Tree_Ornament.png
# bin/negs\Clamp.png
# bin/negs\Claymore.png
# bin/negs\Cloth.png
# bin/negs\Coal.png
# bin/negs\Comb.png
# bin/negs\Composite_Bow.png
# bin/negs\Copper_Chausses.png
# bin/negs\Copper_Hauberk.png
# bin/negs\Copper_Ingot.png
# bin/negs\Copper_Ore.png
# bin/negs\Copper_Shards.png
# bin/negs\Cords.png
# bin/negs\Cursed_Mace.png
# bin/negs\Dagger.png
# bin/negs\Direwolf_Fang.png
# bin/negs\Edict_of_Exile.png
# bin/negs\Empty_Barrel.png
# bin/negs\Empty_Flask.png
# bin/negs\Empty_Vial.png
# bin/negs\Espadon.png
# bin/negs\Executioners_Axe.png
# bin/negs\Executioners_Pannier.png
# bin/negs\Falchlon.png
# bin/negs\Feeding_Trough.png
# bin/negs\Fibula.png
# bin/negs\Flaming_Halbred.png
# bin/negs\Flaming_Sword.png
# bin/negs\Flanged_Mace.png
# bin/negs\Fork.png
# bin/negs\Freezing_Potion.png
# bin/negs\Gamberson.png
# bin/negs\Ghost_Sword.png
# bin/negs\Grate.png
# bin/negs\Grave_Mushroom.png
# bin/negs\Great_Helm.png
# bin/negs\Grinding_Wheel.png
# bin/negs\Gypsy_Mushroom.png
# bin/negs\Halbred.png
# bin/negs\Handle.png
# bin/negs\Hawberries.png
# bin/negs\High_Boots.png
# bin/negs\Holder.png
# bin/negs\Hood.png
# bin/negs\Hourglass.png
# bin/negs\Ice_Axe.png
# bin/negs\Ice_Mace.png
# bin/negs\Ice_Sword.png
# bin/negs\Illuminator.png
# bin/negs\Incense.png
# bin/negs\Iron_Ingot.png
# bin/negs\Iron_Ore.png
# bin/negs\Iron_Plate.png
# bin/negs\Iron_Shod_Shield.png
# bin/negs\Kettle_Hat.png
# bin/negs\Knight_Ruperts_Drops.png
# bin/negs\Knight_Ruperts_Sword.png
# bin/negs\Krelgsmesser.png
# bin/negs\Kris.png
# bin/negs\Leather.png
# bin/negs\Leather_Boots.png
# bin/negs\Leather_Gloves.png
# bin/negs\Leather_Pannier.png
# bin/negs\Leek.png
# bin/negs\Leek_Seed.png
# bin/negs\Left_Alter_Plate.png
# bin/negs\Light_Crossbow.png
# bin/negs\Light_Shield.png
# bin/negs\Lock.png
# bin/negs\Mandrake_Root.png
# bin/negs\Mandrake_Seed.png
# bin/negs\Mandrake_Tincture.png
# bin/negs\Marauders _Axe.png
# bin/negs\Meat.png
# bin/negs\Mechanism.png
# bin/negs\Metioric_Ingot.png
# bin/negs\Mirror.png
# bin/negs\Moonflower.png
# bin/negs\Morningstar.png
# bin/negs\Motar_and_Pestle.png
# bin/negs\Mushroom_Infusion.png
# bin/negs\Mushroom_Soup.png
# bin/negs\Mystics_Pannier.png
# bin/negs\Nails.png
# bin/negs\Night_Guests_Sickle.png
# bin/negs\Oak_Plank.png
# bin/negs\Oar.png
# bin/negs\Oat_Seed.png
# bin/negs\One-Handed_Sword.png
# bin/negs\Philosphers_Stone.png
# bin/negs\Pincers.png
# bin/negs\Pine_Log.png
# bin/negs\Pine_Plank.png
# bin/negs\Pitchfork.png
# bin/negs\Plague_Doctors_Mask.png
# bin/negs\Plated_Chainmail_Gloves.png
# bin/negs\Plum_Pudding.png
# bin/negs\Poision_Dagger.png
# bin/negs\Pot_Helm.png
# bin/negs\Prayer_Bell.png
# bin/negs\Quality_Bowstring.png
# bin/negs\Quilted_Trousers.png
# bin/negs\Raven_Feathers.png
# bin/negs\Retort.png
# bin/negs\Right_Alter_Plate.png
# bin/negs\Ring.png
# bin/negs\Ritual_Mask.png
# bin/negs\Riveted_Boots.png
# bin/negs\Roasted_Turkey.png
# bin/negs\Saddle.png
# bin/negs\Scales.png
# bin/negs\Scale_Armor.png
# bin/negs\Scale_Chausses.png
# bin/negs\Scale_Gauntlets.png
# bin/negs\Scimltar.png
# bin/negs\Scroll_of_Control.png
# bin/negs\Scroll_of_Freezing.png
# bin/negs\Scroll_of_Rain.png
# bin/negs\Scroll_of_Summoning_The_Undead.png
# bin/negs\Scroll_of_Terror.png
# bin/negs\Scythe_Of_Terror.png
# bin/negs\Sickle.png
# bin/negs\SImple_Bow.png
# bin/negs\Simple_Crossbow.png
# bin/negs\Skull.png
# bin/negs\Smasher.png
# bin/negs\Soldiers_Boots.png
# bin/negs\Soul_Cake.png
# bin/negs\Soul_Eater.png
# bin/negs\Sour_Milk.png
# bin/negs\Spade.png
# bin/negs\Spiked_Bracelet.png
# bin/negs\Spiked_Mace.png
# bin/negs\Spirit.png
# bin/negs\Spoon.png
# bin/negs\Stealth_Potion.png
# bin/negs\Steel_Ingot.png
# bin/negs\Stiletto.png
# bin/negs\Stone_Block.png
# bin/negs\St_Peters_Tincture.png
# bin/negs\Sulfer.png
# bin/negs\TD_Key.png
# bin/negs\Thick_Cloth.png
# bin/negs\Throwing_Potion.png
# bin/negs\Tin_Ore.png
# bin/negs\Tournament_Helm.png
# bin/negs\Training_Dummy.png
# bin/negs\Trap.png
# bin/negs\War_Hammer.png
# bin/negs\Wheel.png
# bin/negs\Wire.png
# bin/negs\Wooden_Horse.png

# %%
# Out:
# Named explicitly:
# bin/items\Aissa_Tear.png
# bin/items\AI_Key.png
# bin/items\Alchemaical_Gold.png
# bin/items\Ale.png
# bin/items\Alter_Core.png
# bin/items\Animal_Hide.png
# bin/items\Baked_Pumpkin.png
# bin/items\Bandage.png
# bin/items\Basket_with_Direwolfling.png
# bin/items\Bastard_Sword.png
# bin/items\Berry_drink.png
# bin/items\Birch_Log.png
# bin/items\Birch_Plank.png
# bin/items\Bitter_Tincture.png
# bin/items\Black_Halbred.png
# bin/items\Black_Iron_Shod_Shield.png
# bin/items\Black_Pannier.png
# bin/items\Black_Powder.png
# bin/items\Black_Scimitar.png
# bin/items\Bone.png
# bin/items\Bone_Bow.png
# bin/items\Bone_Mace.png
# bin/items\Book_Of_Fate.png
# bin/items\Bowstring.png
# bin/items\Bridle.png
# bin/items\Brigandine.png
# bin/items\Brigandine_Chausses.png
# bin/items\Brigandine_Gloves.png
# bin/items\Bronze_Chausses.png
# bin/items\Bronze_Hauberk.png
# bin/items\Bronze_Ingot.png
# bin/items\Buckler.png
# bin/items\Candle.png
# bin/items\Candy_Apple.png
# bin/items\Candy_Cane.png
# bin/items\Chain.png
# bin/items\Chainmail_Gauntlets.png
# bin/items\Chainmail_Sabatons.png
# bin/items\Chalice.png
# bin/items\Christmas_Tree_Ornament.png
# bin/items\Clamp.png
# bin/items\Claymore.png
# bin/items\Cloth.png
# bin/items\Coal.png
# bin/items\Comb.png
# bin/items\Composite_Bow.png
# bin/items\Copper_Chausses.png
# bin/items\Copper_Hauberk.png
# bin/items\Copper_Ingot.png
# bin/items\Copper_Ore.png
# bin/items\Copper_Shards.png
# bin/items\Cords.png
# bin/items\Cursed_Mace.png
# bin/items\Dagger.png
# bin/items\Direwolf_Fang.png
# bin/items\Edict_of_Exile.png
# bin/items\Empty_Barrel.png
# bin/items\Empty_Flask.png
# bin/items\Empty_Vial.png
# bin/items\Espadon.png
# bin/items\Executioners_Axe.png
# bin/items\Executioners_Pannier.png
# bin/items\Falchlon.png
# bin/items\Feeding_Trough.png
# bin/items\Fibula.png
# bin/items\Flaming_Halbred.png
# bin/items\Flaming_Sword.png
# bin/items\Flanged_Mace.png
# bin/items\Fork.png
# bin/items\Freezing_Potion.png
# bin/items\Gamberson.png
# bin/items\Ghost_Sword.png
# bin/items\Grate.png
# bin/items\Grave_Mushroom.png
# bin/items\Great_Helm.png
# bin/items\Grinding_Wheel.png
# bin/items\Gypsy_Mushroom.png
# bin/items\Halbred.png
# bin/items\Handle.png
# bin/items\Hawberries.png
# bin/items\High_Boots.png
# bin/items\Holder.png
# bin/items\Hood.png
# bin/items\Hourglass.png
# bin/items\Ice_Axe.png
# bin/items\Ice_Mace.png
# bin/items\Ice_Sword.png
# bin/items\Illuminator.png
# bin/items\Incense.png
# bin/items\Iron_Ingot.png
# bin/items\Iron_Ore.png
# bin/items\Iron_Plate.png
# bin/items\Iron_Shod_Shield.png
# bin/items\Kettle_Hat.png
# bin/items\Knight_Ruperts_Drops.png
# bin/items\Knight_Ruperts_Sword.png
# bin/items\Krelgsmesser.png
# bin/items\Kris.png
# bin/items\Leather.png
# bin/items\Leather_Boots.png
# bin/items\Leather_Gloves.png
# bin/items\Leather_Pannier.png
# bin/items\Leek.png
# bin/items\Leek_Seed.png
# bin/items\Left_Alter_Plate.png
# bin/items\Light_Crossbow.png
# bin/items\Light_Shield.png
# bin/items\Lock.png
# bin/items\Mandrake_Root.png
# bin/items\Mandrake_Seed.png
# bin/items\Mandrake_Tincture.png
# bin/items\Marauders _Axe.png
# bin/items\Meat.png
# bin/items\Mechanism.png
# bin/items\Metioric_Ingot.png
# bin/items\Mirror.png
# bin/items\Moonflower.png
# bin/items\Morningstar.png
# bin/items\Motar_and_Pestle.png
# bin/items\Mushroom_Infusion.png
# bin/items\Mushroom_Soup.png
# bin/items\Mystics_Pannier.png
# bin/items\Nails.png
# bin/items\Night_Guests_Sickle.png
# bin/items\Oak_Plank.png
# bin/items\Oar.png
# bin/items\Oat_Seed.png
# bin/items\One-Handed_Sword.png
# bin/items\Philosphers_Stone.png
# bin/items\Pincers.png
# bin/items\Pine_Log.png
# bin/items\Pine_Plank.png
# bin/items\Pitchfork.png
# bin/items\Plague_Doctors_Mask.png
# bin/items\Plated_Chainmail_Gloves.png
# bin/items\Plum_Pudding.png
# bin/items\Poision_Dagger.png
# bin/items\Pot_Helm.png
# bin/items\Prayer_Bell.png
# bin/items\Quality_Bowstring.png
# bin/items\Quilted_Trousers.png
# bin/items\Raven_Feathers.png
# bin/items\Retort.png
# bin/items\Right_Alter_Plate.png
# bin/items\Ring.png
# bin/items\Ritual_Mask.png
# bin/items\Riveted_Boots.png
# bin/items\Roasted_Turkey.png
# bin/items\Saddle.png
# bin/items\Scales.png
# bin/items\Scale_Armor.png
# bin/items\Scale_Chausses.png
# bin/items\Scale_Gauntlets.png
# bin/items\Scimltar.png
# bin/items\Scroll_of_Control.png
# bin/items\Scroll_of_Freezing.png
# bin/items\Scroll_of_Rain.png
# bin/items\Scroll_of_Summoning_The_Undead.png
# bin/items\Scroll_of_Terror.png
# bin/items\Scythe_Of_Terror.png
# bin/items\Sickle.png
# bin/items\SImple_Bow.png
# bin/items\Simple_Crossbow.png
# bin/items\Skull.png
# bin/items\Smasher.png
# bin/items\Soldiers_Boots.png
# bin/items\Soul_Cake.png
# bin/items\Soul_Eater.png
# bin/items\Sour_Milk.png
# bin/items\Spade.png
# bin/items\Spiked_Bracelet.png
# bin/items\Spiked_Mace.png
# bin/items\Spirit.png
# bin/items\Spoon.png
# bin/items\Stealth_Potion.png
# bin/items\Steel_Ingot.png
# bin/items\Stiletto.png
# bin/items\Stone_Block.png
# bin/items\St_Peters_Tincture.png
# bin/items\Sulfer.png
# bin/items\TD_Key.png
# bin/items\Thick_Cloth.png
# bin/items\Throwing_Potion.png
# bin/items\Tin_Ore.png
# bin/items\Tournament_Helm.png
# bin/items\Training_Dummy.png
# bin/items\Trap.png
# bin/items\War_Hammer.png
# bin/items\Wheel.png
# bin/items\Wire.png
# bin/items\Wooden_Horse.png

# %%
import os, shutil
dir_name = '\bin\Items'
for i in files:
    os.mkdir(os.path.join(dir_name, i))
    shutil.copy(os.path.join(dir_name , i), os.path.join(dir_name , i.split(".")[0]))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-31-030f88dca5ae> in <module>
#       1 import os, shutil
#       2 dir_name = '\bin\Items'
# ----> 3 for i in files:
#       4     os.mkdir(os.path.join(dir_name, i))
#       5     shutil.copy(os.path.join(dir_name , i), os.path.join(dir_name , i.split(".")[0]))
#
# NameError: name 'files' is not defined
